# %%
import pandas as pd
import numpy

# %%
df=pd.read_csv(r"C:\Users\OM\Desktop\Anvesshan\all_mfccs_features_30ms_mean.csv")
df
# Out:
#        mfcc_1     mfcc_2     mfcc_3     mfcc_4    mfcc_5     mfcc_6  \
# 0  -543.34070  59.242690  -2.075722  11.764300  9.415854  -6.574404
# 1  -456.46063  44.242104  -6.012435   4.304442  8.389402  -4.933662
# 2  -518.12604  48.798990 -14.110176  -7.302918  2.941289  13.348977
# 3  -611.73480  29.619112   1.273480   9.717866 -1.051459  -1.886757
# 4  -487.77136  62.416843  -3.455845  -0.088642 -6.706918  -7.196074
# ..        ...        ...        ...        ...       ...        ...
# 95 -582.64905  26.680304   9.501963   5.222083  6.540722  -9.540854
# 96 -685.04004  21.641779   7.058707  14.345130 -0.411432  -5.660082
# 97 -751.46204  51.895798 -17.114979  12.468782  7.811354  -4.403554
# 98 -990.64276  12.180866  -1.104389   2.646423  1.420789  -3.193024
# 99 -816.32860  44.339970   1.029514   7.410937  0.151334  -7.764560
#
#        mfcc_7    mfcc_8    mfcc_9   mfcc_10  ...  double_delta_mfcc_5  \
# 0    0.557385  3.340566 -4.351322  0.643784  ...           -32.817516
# ...

# %%
df
# Out:
#        mfcc_1     mfcc_2     mfcc_3     mfcc_4    mfcc_5     mfcc_6  \
# 0  -543.34070  59.242690  -2.075722  11.764300  9.415854  -6.574404
# 1  -456.46063  44.242104  -6.012435   4.304442  8.389402  -4.933662
# 2  -518.12604  48.798990 -14.110176  -7.302918  2.941289  13.348977
# 3  -611.73480  29.619112   1.273480   9.717866 -1.051459  -1.886757
# 4  -487.77136  62.416843  -3.455845  -0.088642 -6.706918  -7.196074
# ..        ...        ...        ...        ...       ...        ...
# 95 -582.64905  26.680304   9.501963   5.222083  6.540722  -9.540854
# 96 -685.04004  21.641779   7.058707  14.345130 -0.411432  -5.660082
# 97 -751.46204  51.895798 -17.114979  12.468782  7.811354  -4.403554
# 98 -990.64276  12.180866  -1.104389   2.646423  1.420789  -3.193024
# 99 -816.32860  44.339970   1.029514   7.410937  0.151334  -7.764560
#
#        mfcc_7    mfcc_8    mfcc_9   mfcc_10  ...  double_delta_mfcc_5  \
# 0    0.557385  3.340566 -4.351322  0.643784  ...           -32.817516
# ...

# %%
df1=pd.read_csv("C:/Users/OM/Desktop/Anvesshan/newdataset_new.csv")

# %%
df1
# Out:
#     Unnamed: 0.1  Unnamed: 0     mfcc_1     mfcc_2     mfcc_3     mfcc_4  \
# 0              0           0 -543.34070  59.242690  -2.075722  11.764300
# 1              1           1 -456.46063  44.242104  -6.012435   4.304442
# 2              2           2 -518.12604  48.798990 -14.110176  -7.302918
# 3              3           3 -611.73480  29.619112   1.273480   9.717866
# 4              4           4 -487.77136  62.416843  -3.455845  -0.088642
# ..           ...         ...        ...        ...        ...        ...
# 95            95          95 -582.64905  26.680304   9.501963   5.222083
# 96            96          96 -685.04004  21.641779   7.058707  14.345130
# 97            97          97 -751.46204  51.895798 -17.114979  12.468782
# 98            98          98 -990.64276  12.180866  -1.104389   2.646423
# 99            99          99 -816.32860  44.339970   1.029514   7.410937
#
#       mfcc_5     mfcc_6     mfcc_7    mfcc_8  ...  Standard Deviation ZCR  \
# ...

# %%
df1 = df1.drop(
    columns=[
        "Unnamed: 0.1", "mfcc_1", "mfcc_2", "mfcc_3", "file", "Unnamed: 0", 
        "File Name", "date", "time", "datetime", "mfcc_4", "mfcc_5", 
        "mfcc_6", "mfcc_7", "mfcc_8", "mfcc_9", "mfcc_10", "mfcc_11", 
        "mfcc_12", "mfcc_12", "mfcc_13", "delta_mfcc_1", "delta_mfcc_2", 
        "delta_mfcc_3", "delta_mfcc_4", "delta_mfcc_5", "delta_mfcc_6", 
        "delta_mfcc_7", "delta_mfcc_8", "delta_mfcc_9", "delta_mfcc_10", 
        "delta_mfcc_11", "delta_mfcc_12", "delta_mfcc_13","Unnamed: 0.2","File"
    ], 
    axis=1, 
    errors='ignore'
)

# %%
df1
# Out:
#     double_delta_mfcc_1  double_delta_mfcc_2  double_delta_mfcc_3  \
# 0            -32.817516           -32.817516           -32.817516
# 1            -27.567123           -27.567123           -27.567123
# 2            -30.114073           -30.114073           -30.114073
# 3            -36.702995           -36.702995           -36.702995
# 4            -28.101492           -28.101492           -28.101492
# ..                  ...                  ...                  ...
# 95           -35.490467           -35.490467           -35.490467
# 96           -41.785710           -41.785710           -41.785710
# 97           -44.668800           -44.668800           -44.668800
# 98           -59.886196           -59.886196           -59.886196
# 99           -48.964073           -48.964073           -48.964073
#
#     double_delta_mfcc_4  double_delta_mfcc_5  double_delta_mfcc_6  \
# 0            -32.817516           -32.817516             3.188173
# ...

# %%
merged_df = pd.merge(df, df1, left_index=True, right_index=True)
# Out:
# ---------------------------------------------------------------------------
# MergeError                                Traceback (most recent call last)
# Cell In[110], line 1
# ----> 1 merged_df = pd.merge(df, df1, left_index=True, right_index=True)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\reshape\merge.py:162, in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     131 @Substitution("\nleft : DataFrame or named Series")
#     132 @Appender(_merge_doc, indents=0)
#     133 def merge(
#    (...)
#     146     validate: str | None = None,
#     147 ) -> DataFrame:
#     148     op = _MergeOperation(
#     149         left,
#     150         right,
#    (...)
#     160         validate=validate,
#     161     )
# --> 162     return op.get_result(copy=copy)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\reshape\merge.py:811, in _MergeOperation.get_result(self, copy)
# ...

# %%
merged_df
# Out:
#        mfcc_1     mfcc_2     mfcc_3     mfcc_4    mfcc_5     mfcc_6  \
# 0  -543.34070  59.242690  -2.075722  11.764300  9.415854  -6.574404
# 1  -456.46063  44.242104  -6.012435   4.304442  8.389402  -4.933662
# 2  -518.12604  48.798990 -14.110176  -7.302918  2.941289  13.348977
# 3  -611.73480  29.619112   1.273480   9.717866 -1.051459  -1.886757
# 4  -487.77136  62.416843  -3.455845  -0.088642 -6.706918  -7.196074
# ..        ...        ...        ...        ...       ...        ...
# 95 -582.64905  26.680304   9.501963   5.222083  6.540722  -9.540854
# 96 -685.04004  21.641779   7.058707  14.345130 -0.411432  -5.660082
# 97 -751.46204  51.895798 -17.114979  12.468782  7.811354  -4.403554
# 98 -990.64276  12.180866  -1.104389   2.646423  1.420789  -3.193024
# 99 -816.32860  44.339970   1.029514   7.410937  0.151334  -7.764560
#
#        mfcc_7    mfcc_8    mfcc_9   mfcc_10  ...  Standard Deviation ZCR  \
# 0    0.557385  3.340566 -4.351322  0.643784  ...                0.051878
# ...

# %%
merged_df.to_csv("C:/Users/OM/Desktop/Anvesshan/newdataset_new.csv")

# %%
df3=pd.read_csv("C:/Users/OM/Desktop/Anvesshan/newdataset_new.csv")

# %%
df3
# Out:
#     Unnamed: 0     mfcc_1     mfcc_2     mfcc_3     mfcc_4    mfcc_5  \
# 0            0 -543.34070  59.242690  -2.075722  11.764300  9.415854
# 1            1 -456.46063  44.242104  -6.012435   4.304442  8.389402
# 2            2 -518.12604  48.798990 -14.110176  -7.302918  2.941289
# 3            3 -611.73480  29.619112   1.273480   9.717866 -1.051459
# 4            4 -487.77136  62.416843  -3.455845  -0.088642 -6.706918
# ..         ...        ...        ...        ...        ...       ...
# 95          95 -582.64905  26.680304   9.501963   5.222083  6.540722
# 96          96 -685.04004  21.641779   7.058707  14.345130 -0.411432
# 97          97 -751.46204  51.895798 -17.114979  12.468782  7.811354
# 98          98 -990.64276  12.180866  -1.104389   2.646423  1.420789
# 99          99 -816.32860  44.339970   1.029514   7.410937  0.151334
#
#        mfcc_6     mfcc_7    mfcc_8    mfcc_9  ...  Standard Deviation ZCR  \
# ...

# %%
df3=df3.to_csv(r"C:\Users\OM\Desktop\Anvesshan\newdataset_new.csv")

# %%
df3

# %%
df3=df3.drop(columns=["file"],axis=1,erros='ignore')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[94], line 1
# ----> 1 df3=df3.drop(columns=["file"],axis=1,erros='ignore')
#
# AttributeError: 'NoneType' object has no attribute 'drop'
