# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv(r"C:\Users\OM\Desktop\Anvesshan\newdataset_new.csv")

# %%
df
# Out:
#     Unnamed: 0.2                                File  Mean ZCR  Peak ZCR  \
# 0              0    Final_supported_file/output1.wav  0.069555  0.251953
# 1              1    Final_supported_file/output2.wav  0.089414  0.208008
# 2              2    Final_supported_file/output3.wav  0.124511  0.443359
# 3              3    Final_supported_file/output4.wav  0.115067  0.397461
# 4              4    Final_supported_file/output5.wav  0.072062  0.246094
# ..           ...                                 ...       ...       ...
# 95            95   Final_supported_file/output96.wav  0.103238  0.430664
# 96            96   Final_supported_file/output97.wav  0.085264  0.197754
# 97            97   Final_supported_file/output98.wav  0.118198  0.438477
# 98            98   Final_supported_file/output99.wav  0.020425  0.403320
# 99            99  Final_supported_file/output100.wav  0.105165  0.243652
#
#     Standard Deviation ZCR  Unnamed: 0.1      mfcc_1      mfcc_2     mfcc_3  \
# ...

# %%
df=df.drop(df['File'],axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 df=df.drop(df['File'],axis=1)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\frame.py:5258, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5110 def drop(
#    5111     self,
#    5112     labels: IndexLabel = None,
#    (...)
#    5119     errors: IgnoreRaise = "raise",
#    5120 ) -> DataFrame | None:
#    5121     """
#    5122     Drop specified labels from rows or columns.
#    5123
#    (...)
#    5256             weight  1.0     0.8
#    5257     """
# -> 5258     return super().drop(
#    5259         labels=labels,
#    5260         axis=axis,
#    5261         index=index,
#    5262         columns=columns,
#    5263         level=level,
#    5264         inplace=inplace,
#    5265         errors=errors,
#    5266     )
#
# ...
