# %%
import pandas as pd 
import numpy as np

# %%
df=pd.read_csv(r"C:\Users\OM\Desktop\Anvesshan\CSV_files\newdataset_with_segmented_mfcc.csv")

# %%
df
# Out:
#     Unnamed: 0     mfcc_1     mfcc_2     mfcc_3     mfcc_4    mfcc_5  \
# 0            0 -543.34070  59.242690  -2.075722  11.764300  9.415854
# 1            1 -456.46063  44.242104  -6.012435   4.304442  8.389402
# 2            2 -518.12604  48.798990 -14.110176  -7.302918  2.941289
# 3            3 -611.73480  29.619112   1.273480   9.717866 -1.051459
# 4            4 -487.77136  62.416843  -3.455845  -0.088642 -6.706918
# ..         ...        ...        ...        ...        ...       ...
# 95          95 -582.64905  26.680304   9.501963   5.222083  6.540722
# 96          96 -685.04004  21.641779   7.058707  14.345130 -0.411432
# 97          97 -751.46204  51.895798 -17.114979  12.468782  7.811354
# 98          98 -990.64276  12.180866  -1.104389   2.646423  1.420789
# 99          99 -816.32860  44.339970   1.029514   7.410937  0.151334
#
#        mfcc_6     mfcc_7    mfcc_8    mfcc_9  ...  Standard Deviation ZCR  \
# 0   -6.574404   0.557385  3.340566 -4.351322  ...                0.051878
# 1   -4.933662  -9.869618 -2.349937 -7.797264  ...                0.043254
# 2   13.348977  -4.090949  1.654122  9.201992  ...                0.104739
# 3   -1.886757  -2.090428 -0.093933  2.524244  ...                0.067878
# 4   -7.196074 -13.816851 -3.841252 -4.695722  ...                0.049991
# ..        ...        ...       ...       ...  ...                     ...
# 95  -9.540854  -5.466430 -2.378820 -5.816207  ...                0.074160
# 96  -5.660082  -8.212572 -0.187042 -5.138319  ...                0.044620
# 97  -4.403554   0.797049 -1.277087  7.586171  ...                0.075565
# 98  -3.193024  -1.748005  1.748474 -1.093798  ...                0.049228
# 99  -7.764560  -5.848500 -1.252969 -3.833778  ...                0.050918
#
#     Mean Spectral Centroid  Std Dev Spectral Centroid  Max Spectral Centroid  \
# 0              2241.649014                1407.188645           16535.937650
# 1              2554.366529                 888.343405            7129.317871
# 2              3920.614451                2246.778404           10313.648460
# 3              3274.478870                1691.015848           16911.326720
# 4              2167.719218                1002.818920            5213.814000
# ..                     ...                        ...                    ...
# 95             2711.568449                1889.874662           17396.182810
# 96             3083.985651                1138.634264            5784.491613
# 97             3941.240679                1640.927114           10367.509450
# 98              769.558021                1749.204722           16031.114670
# 99             3809.017925                1394.205142            6435.960797
#
#     Min Spectral Centroid  age  gender  mild  severe  pseudocough
# 0                0.000000   35    male     2       0            0
# 1              472.152477   23  female     2       0            0
# 2                0.000000   28    male     0       0            1
# 3                0.000000   28  female     2       0            0
# 4              532.233677   44    male     0       0            1
# ..                    ...  ...     ...   ...     ...          ...
# 95               0.000000   20    male     2       0            0
# 96               0.000000   24    male     2       0            0
# 97               0.000000   35  female     2       0            0
# 98               0.000000   40    male     0       0            1
# 99               0.000000   29    male     2       0            0
#
# [100 rows x 78 columns]

# %%
df=df.drop(columns=["Unnamed: 0"], axis=1,errors='ignore')

# %%
df
# Out:
#        mfcc_1     mfcc_2     mfcc_3     mfcc_4    mfcc_5     mfcc_6  \
# 0  -543.34070  59.242690  -2.075722  11.764300  9.415854  -6.574404
# 1  -456.46063  44.242104  -6.012435   4.304442  8.389402  -4.933662
# 2  -518.12604  48.798990 -14.110176  -7.302918  2.941289  13.348977
# 3  -611.73480  29.619112   1.273480   9.717866 -1.051459  -1.886757
# 4  -487.77136  62.416843  -3.455845  -0.088642 -6.706918  -7.196074
# ..        ...        ...        ...        ...       ...        ...
# 95 -582.64905  26.680304   9.501963   5.222083  6.540722  -9.540854
# 96 -685.04004  21.641779   7.058707  14.345130 -0.411432  -5.660082
# 97 -751.46204  51.895798 -17.114979  12.468782  7.811354  -4.403554
# 98 -990.64276  12.180866  -1.104389   2.646423  1.420789  -3.193024
# 99 -816.32860  44.339970   1.029514   7.410937  0.151334  -7.764560
#
#        mfcc_7    mfcc_8    mfcc_9   mfcc_10  ...  Standard Deviation ZCR  \
# 0    0.557385  3.340566 -4.351322  0.643784  ...                0.051878
# 1   -9.869618 -2.349937 -7.797264  0.339263  ...                0.043254
# 2   -4.090949  1.654122  9.201992  0.545845  ...                0.104739
# 3   -2.090428 -0.093933  2.524244 -5.492090  ...                0.067878
# 4  -13.816851 -3.841252 -4.695722  0.875052  ...                0.049991
# ..        ...       ...       ...       ...  ...                     ...
# 95  -5.466430 -2.378820 -5.816207 -4.557632  ...                0.074160
# 96  -8.212572 -0.187042 -5.138319 -0.398012  ...                0.044620
# 97   0.797049 -1.277087  7.586171 -3.246748  ...                0.075565
# 98  -1.748005  1.748474 -1.093798 -1.404210  ...                0.049228
# 99  -5.848500 -1.252969 -3.833778 -0.899066  ...                0.050918
#
#     Mean Spectral Centroid  Std Dev Spectral Centroid  Max Spectral Centroid  \
# 0              2241.649014                1407.188645           16535.937650
# 1              2554.366529                 888.343405            7129.317871
# 2              3920.614451                2246.778404           10313.648460
# 3              3274.478870                1691.015848           16911.326720
# 4              2167.719218                1002.818920            5213.814000
# ..                     ...                        ...                    ...
# 95             2711.568449                1889.874662           17396.182810
# 96             3083.985651                1138.634264            5784.491613
# 97             3941.240679                1640.927114           10367.509450
# 98              769.558021                1749.204722           16031.114670
# 99             3809.017925                1394.205142            6435.960797
#
#     Min Spectral Centroid  age  gender  mild  severe  pseudocough
# 0                0.000000   35    male     2       0            0
# 1              472.152477   23  female     2       0            0
# 2                0.000000   28    male     0       0            1
# 3                0.000000   28  female     2       0            0
# 4              532.233677   44    male     0       0            1
# ..                    ...  ...     ...   ...     ...          ...
# 95               0.000000   20    male     2       0            0
# 96               0.000000   24    male     2       0            0
# 97               0.000000   35  female     2       0            0
# 98               0.000000   40    male     0       0            1
# 99               0.000000   29    male     2       0            0
#
# [100 rows x 77 columns]

# %%
import pandas as pd


# Create a new target column based on the conditions
def classify_cough(row):
    if row['mild'] == 2:
        return 2
    elif row['severe'] == 3:
        return 3
    elif row['pseudocough'] == 1:
        return 1
    else:
        return 0  # Default value if none of the conditions match

# Apply the function to each row
df['target'] = df.apply(lambda row: classify_cough(row), axis=1)

# Save the updated CSV
df.to_csv('updated_file.csv', index=False)

# %%
df
# Out:
#        mfcc_1     mfcc_2     mfcc_3     mfcc_4    mfcc_5     mfcc_6  \
# 0  -543.34070  59.242690  -2.075722  11.764300  9.415854  -6.574404
# 1  -456.46063  44.242104  -6.012435   4.304442  8.389402  -4.933662
# 2  -518.12604  48.798990 -14.110176  -7.302918  2.941289  13.348977
# 3  -611.73480  29.619112   1.273480   9.717866 -1.051459  -1.886757
# 4  -487.77136  62.416843  -3.455845  -0.088642 -6.706918  -7.196074
# ..        ...        ...        ...        ...       ...        ...
# 95 -582.64905  26.680304   9.501963   5.222083  6.540722  -9.540854
# 96 -685.04004  21.641779   7.058707  14.345130 -0.411432  -5.660082
# 97 -751.46204  51.895798 -17.114979  12.468782  7.811354  -4.403554
# 98 -990.64276  12.180866  -1.104389   2.646423  1.420789  -3.193024
# 99 -816.32860  44.339970   1.029514   7.410937  0.151334  -7.764560
#
#        mfcc_7    mfcc_8    mfcc_9   mfcc_10  ...  Mean Spectral Centroid  \
# 0    0.557385  3.340566 -4.351322  0.643784  ...             2241.649014
# 1   -9.869618 -2.349937 -7.797264  0.339263  ...             2554.366529
# 2   -4.090949  1.654122  9.201992  0.545845  ...             3920.614451
# 3   -2.090428 -0.093933  2.524244 -5.492090  ...             3274.478870
# 4  -13.816851 -3.841252 -4.695722  0.875052  ...             2167.719218
# ..        ...       ...       ...       ...  ...                     ...
# 95  -5.466430 -2.378820 -5.816207 -4.557632  ...             2711.568449
# 96  -8.212572 -0.187042 -5.138319 -0.398012  ...             3083.985651
# 97   0.797049 -1.277087  7.586171 -3.246748  ...             3941.240679
# 98  -1.748005  1.748474 -1.093798 -1.404210  ...              769.558021
# 99  -5.848500 -1.252969 -3.833778 -0.899066  ...             3809.017925
#
#     Std Dev Spectral Centroid  Max Spectral Centroid  Min Spectral Centroid  \
# 0                 1407.188645           16535.937650               0.000000
# 1                  888.343405            7129.317871             472.152477
# 2                 2246.778404           10313.648460               0.000000
# 3                 1691.015848           16911.326720               0.000000
# 4                 1002.818920            5213.814000             532.233677
# ..                        ...                    ...                    ...
# 95                1889.874662           17396.182810               0.000000
# 96                1138.634264            5784.491613               0.000000
# 97                1640.927114           10367.509450               0.000000
# 98                1749.204722           16031.114670               0.000000
# 99                1394.205142            6435.960797               0.000000
#
#     age  gender  mild  severe  pseudocough  target
# 0    35    male     2       0            0       2
# 1    23  female     2       0            0       2
# 2    28    male     0       0            1       1
# 3    28  female     2       0            0       2
# 4    44    male     0       0            1       1
# ..  ...     ...   ...     ...          ...     ...
# 95   20    male     2       0            0       2
# 96   24    male     2       0            0       2
# 97   35  female     2       0            0       2
# 98   40    male     0       0            1       1
# 99   29    male     2       0            0       2
#
# [100 rows x 78 columns]

# %%
y=df["target"]

# %%
y
# Out:
# 0     2
# 1     2
# 2     1
# 3     2
# 4     1
#      ..
# 95    2
# 96    2
# 97    2
# 98    1
# 99    2
# Name: target, Length: 100, dtype: int64

# %%
df=df.drop(columns=["target","mild","severe","pseudocough"], axis=1,errors='ignore')

# %%
df
# Out:
#        mfcc_1     mfcc_2     mfcc_3     mfcc_4    mfcc_5     mfcc_6  \
# 0  -543.34070  59.242690  -2.075722  11.764300  9.415854  -6.574404
# 1  -456.46063  44.242104  -6.012435   4.304442  8.389402  -4.933662
# 2  -518.12604  48.798990 -14.110176  -7.302918  2.941289  13.348977
# 3  -611.73480  29.619112   1.273480   9.717866 -1.051459  -1.886757
# 4  -487.77136  62.416843  -3.455845  -0.088642 -6.706918  -7.196074
# ..        ...        ...        ...        ...       ...        ...
# 95 -582.64905  26.680304   9.501963   5.222083  6.540722  -9.540854
# 96 -685.04004  21.641779   7.058707  14.345130 -0.411432  -5.660082
# 97 -751.46204  51.895798 -17.114979  12.468782  7.811354  -4.403554
# 98 -990.64276  12.180866  -1.104389   2.646423  1.420789  -3.193024
# 99 -816.32860  44.339970   1.029514   7.410937  0.151334  -7.764560
#
#        mfcc_7    mfcc_8    mfcc_9   mfcc_10  ...  double_delta_mfcc_13_y  \
# 0    0.557385  3.340566 -4.351322  0.643784  ...                0.548926
# 1   -9.869618 -2.349937 -7.797264  0.339263  ...                1.215293
# 2   -4.090949  1.654122  9.201992  0.545845  ...               -0.360332
# 3   -2.090428 -0.093933  2.524244 -5.492090  ...               -0.276118
# 4  -13.816851 -3.841252 -4.695722  0.875052  ...                0.175365
# ..        ...       ...       ...       ...  ...                     ...
# 95  -5.466430 -2.378820 -5.816207 -4.557632  ...                0.812088
# 96  -8.212572 -0.187042 -5.138319 -0.398012  ...                0.313886
# 97   0.797049 -1.277087  7.586171 -3.246748  ...                0.184225
# 98  -1.748005  1.748474 -1.093798 -1.404210  ...                0.135356
# 99  -5.848500 -1.252969 -3.833778 -0.899066  ...                0.365224
#
#     Mean ZCR  Peak ZCR  Standard Deviation ZCR  Mean Spectral Centroid  \
# 0   0.069555  0.251953                0.051878             2241.649014
# 1   0.089414  0.208008                0.043254             2554.366529
# 2   0.124511  0.443359                0.104739             3920.614451
# 3   0.115067  0.397461                0.067878             3274.478870
# 4   0.072062  0.246094                0.049991             2167.719218
# ..       ...       ...                     ...                     ...
# 95  0.103238  0.430664                0.074160             2711.568449
# 96  0.085264  0.197754                0.044620             3083.985651
# 97  0.118198  0.438477                0.075565             3941.240679
# 98  0.020425  0.403320                0.049228              769.558021
# 99  0.105165  0.243652                0.050918             3809.017925
#
#     Std Dev Spectral Centroid  Max Spectral Centroid  Min Spectral Centroid  \
# 0                 1407.188645           16535.937650               0.000000
# 1                  888.343405            7129.317871             472.152477
# 2                 2246.778404           10313.648460               0.000000
# 3                 1691.015848           16911.326720               0.000000
# 4                 1002.818920            5213.814000             532.233677
# ..                        ...                    ...                    ...
# 95                1889.874662           17396.182810               0.000000
# 96                1138.634264            5784.491613               0.000000
# 97                1640.927114           10367.509450               0.000000
# 98                1749.204722           16031.114670               0.000000
# 99                1394.205142            6435.960797               0.000000
#
#     age  gender
# 0    35    male
# 1    23  female
# 2    28    male
# 3    28  female
# 4    44    male
# ..  ...     ...
# 95   20    male
# 96   24    male
# 97   35  female
# 98   40    male
# 99   29    male
#
# [100 rows x 74 columns]

# %%
import pandas as pd


# Create a new target column based on the conditions
def classify_gender(row):
    if row['gender'] == 'male':
        return 2
    else:
        return 1  # Default value if none of the conditions match

# Apply the function to each row
df['Gender'] = df.apply(lambda row: classify_gender(row), axis=1)

# Save the updated CSV
df.to_csv('updated_file.csv', index=False)

# %%
df
# Out:
#        mfcc_1     mfcc_2     mfcc_3     mfcc_4    mfcc_5     mfcc_6  \
# 0  -543.34070  59.242690  -2.075722  11.764300  9.415854  -6.574404
# 1  -456.46063  44.242104  -6.012435   4.304442  8.389402  -4.933662
# 2  -518.12604  48.798990 -14.110176  -7.302918  2.941289  13.348977
# 3  -611.73480  29.619112   1.273480   9.717866 -1.051459  -1.886757
# 4  -487.77136  62.416843  -3.455845  -0.088642 -6.706918  -7.196074
# ..        ...        ...        ...        ...       ...        ...
# 95 -582.64905  26.680304   9.501963   5.222083  6.540722  -9.540854
# 96 -685.04004  21.641779   7.058707  14.345130 -0.411432  -5.660082
# 97 -751.46204  51.895798 -17.114979  12.468782  7.811354  -4.403554
# 98 -990.64276  12.180866  -1.104389   2.646423  1.420789  -3.193024
# 99 -816.32860  44.339970   1.029514   7.410937  0.151334  -7.764560
#
#        mfcc_7    mfcc_8    mfcc_9   mfcc_10  ...  Mean ZCR  Peak ZCR  \
# 0    0.557385  3.340566 -4.351322  0.643784  ...  0.069555  0.251953
# 1   -9.869618 -2.349937 -7.797264  0.339263  ...  0.089414  0.208008
# 2   -4.090949  1.654122  9.201992  0.545845  ...  0.124511  0.443359
# 3   -2.090428 -0.093933  2.524244 -5.492090  ...  0.115067  0.397461
# 4  -13.816851 -3.841252 -4.695722  0.875052  ...  0.072062  0.246094
# ..        ...       ...       ...       ...  ...       ...       ...
# 95  -5.466430 -2.378820 -5.816207 -4.557632  ...  0.103238  0.430664
# 96  -8.212572 -0.187042 -5.138319 -0.398012  ...  0.085264  0.197754
# 97   0.797049 -1.277087  7.586171 -3.246748  ...  0.118198  0.438477
# 98  -1.748005  1.748474 -1.093798 -1.404210  ...  0.020425  0.403320
# 99  -5.848500 -1.252969 -3.833778 -0.899066  ...  0.105165  0.243652
#
#     Standard Deviation ZCR  Mean Spectral Centroid  Std Dev Spectral Centroid  \
# 0                 0.051878             2241.649014                1407.188645
# 1                 0.043254             2554.366529                 888.343405
# 2                 0.104739             3920.614451                2246.778404
# 3                 0.067878             3274.478870                1691.015848
# 4                 0.049991             2167.719218                1002.818920
# ..                     ...                     ...                        ...
# 95                0.074160             2711.568449                1889.874662
# 96                0.044620             3083.985651                1138.634264
# 97                0.075565             3941.240679                1640.927114
# 98                0.049228              769.558021                1749.204722
# 99                0.050918             3809.017925                1394.205142
#
#     Max Spectral Centroid  Min Spectral Centroid  age  gender  Gender
# 0            16535.937650               0.000000   35    male       2
# 1             7129.317871             472.152477   23  female       1
# 2            10313.648460               0.000000   28    male       2
# 3            16911.326720               0.000000   28  female       1
# 4             5213.814000             532.233677   44    male       2
# ..                    ...                    ...  ...     ...     ...
# 95           17396.182810               0.000000   20    male       2
# 96            5784.491613               0.000000   24    male       2
# 97           10367.509450               0.000000   35  female       1
# 98           16031.114670               0.000000   40    male       2
# 99            6435.960797               0.000000   29    male       2
#
# [100 rows x 75 columns]

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(8,6))
sns.countplot(x='Gender', data=df, palette='viridis')

# Add title and labels
plt.title('Class Distribution in Gender  Column', fontsize=15)
plt.xlabel('Gender count', fontsize=12)
plt.ylabel('Count', fontsize=12)

# Show the plot
plt.show()
# Out:
# C:\Users\OM\AppData\Local\Temp\ipykernel_11408\4082373475.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Gender', data=df, palette='viridis')

# %%
df=df.drop(columns=["gender"], axis=1,errors='ignore')

# %%
df
# Out:
#        mfcc_1     mfcc_2     mfcc_3     mfcc_4    mfcc_5     mfcc_6  \
# 0  -543.34070  59.242690  -2.075722  11.764300  9.415854  -6.574404
# 1  -456.46063  44.242104  -6.012435   4.304442  8.389402  -4.933662
# 2  -518.12604  48.798990 -14.110176  -7.302918  2.941289  13.348977
# 3  -611.73480  29.619112   1.273480   9.717866 -1.051459  -1.886757
# 4  -487.77136  62.416843  -3.455845  -0.088642 -6.706918  -7.196074
# ..        ...        ...        ...        ...       ...        ...
# 95 -582.64905  26.680304   9.501963   5.222083  6.540722  -9.540854
# 96 -685.04004  21.641779   7.058707  14.345130 -0.411432  -5.660082
# 97 -751.46204  51.895798 -17.114979  12.468782  7.811354  -4.403554
# 98 -990.64276  12.180866  -1.104389   2.646423  1.420789  -3.193024
# 99 -816.32860  44.339970   1.029514   7.410937  0.151334  -7.764560
#
#        mfcc_7    mfcc_8    mfcc_9   mfcc_10  ...  double_delta_mfcc_13_y  \
# 0    0.557385  3.340566 -4.351322  0.643784  ...                0.548926
# 1   -9.869618 -2.349937 -7.797264  0.339263  ...                1.215293
# 2   -4.090949  1.654122  9.201992  0.545845  ...               -0.360332
# 3   -2.090428 -0.093933  2.524244 -5.492090  ...               -0.276118
# 4  -13.816851 -3.841252 -4.695722  0.875052  ...                0.175365
# ..        ...       ...       ...       ...  ...                     ...
# 95  -5.466430 -2.378820 -5.816207 -4.557632  ...                0.812088
# 96  -8.212572 -0.187042 -5.138319 -0.398012  ...                0.313886
# 97   0.797049 -1.277087  7.586171 -3.246748  ...                0.184225
# 98  -1.748005  1.748474 -1.093798 -1.404210  ...                0.135356
# 99  -5.848500 -1.252969 -3.833778 -0.899066  ...                0.365224
#
#     Mean ZCR  Peak ZCR  Standard Deviation ZCR  Mean Spectral Centroid  \
# 0   0.069555  0.251953                0.051878             2241.649014
# 1   0.089414  0.208008                0.043254             2554.366529
# 2   0.124511  0.443359                0.104739             3920.614451
# 3   0.115067  0.397461                0.067878             3274.478870
# 4   0.072062  0.246094                0.049991             2167.719218
# ..       ...       ...                     ...                     ...
# 95  0.103238  0.430664                0.074160             2711.568449
# 96  0.085264  0.197754                0.044620             3083.985651
# 97  0.118198  0.438477                0.075565             3941.240679
# 98  0.020425  0.403320                0.049228              769.558021
# 99  0.105165  0.243652                0.050918             3809.017925
#
#     Std Dev Spectral Centroid  Max Spectral Centroid  Min Spectral Centroid  \
# 0                 1407.188645           16535.937650               0.000000
# 1                  888.343405            7129.317871             472.152477
# 2                 2246.778404           10313.648460               0.000000
# 3                 1691.015848           16911.326720               0.000000
# 4                 1002.818920            5213.814000             532.233677
# ..                        ...                    ...                    ...
# 95                1889.874662           17396.182810               0.000000
# 96                1138.634264            5784.491613               0.000000
# 97                1640.927114           10367.509450               0.000000
# 98                1749.204722           16031.114670               0.000000
# 99                1394.205142            6435.960797               0.000000
#
#     age  Gender
# 0    35       2
# 1    23       1
# 2    28       2
# 3    28       1
# 4    44       2
# ..  ...     ...
# 95   20       2
# 96   24       2
# 97   35       1
# 98   40       2
# 99   29       2
#
# [100 rows x 74 columns]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(df, y, test_size=0.2, random_state=42, stratify=y)

# %%
from imblearn.over_sampling import SMOTE

smote = SMOTE(random_state=42)

X_train_sm, y_train_sm = smote.fit_resample(X_train, y_train)

# %%
print("Class distribution after SMOTE:", y_train_sm.value_counts())
# Out:
# Class distribution after SMOTE: target
# 2    46
# 1    46
# 3    46
# Name: count, dtype: int64

# %%
from sklearn.ensemble import HistGradientBoostingClassifier
from sklearn.metrics import accuracy_score
# Assuming Xtrain contains your training features and ytrain_discrete contains discrete class labels
new0=HistGradientBoostingClassifier()
new0.fit(X_train_sm,y_train_sm)
# Out:
# HistGradientBoostingClassifier()

# %%
from sklearn.model_selection import RandomizedSearchCV
from scipy.stats import uniform
param_distributions = {
    'learning_rate': uniform(loc=0.01, scale=0.2),
    'max_iter': [100, 200, 300],
    'max_depth': [3, 5, 7],
    'min_samples_leaf': [1, 2, 4],
    'l2_regularization': uniform(loc=0.0, scale=1.0),
}
random_search = RandomizedSearchCV(new0, param_distributions, random_state=42)
random_search.fit(X_train_sm,y_train_sm)
# Out:
# RandomizedSearchCV(estimator=HistGradientBoostingClassifier(),
#                    param_distributions={'l2_regularization': <scipy.stats._distn_infrastructure.rv_continuous_frozen object at 0x000001F42DD6DD10>,
#                                         'learning_rate': <scipy.stats._distn_infrastructure.rv_continuous_frozen object at 0x000001F42DD6D4D0>,
#                                         'max_depth': [3, 5, 7],
#                                         'max_iter': [100, 200, 300],
#                                         'min_samples_leaf': [1, 2, 4]},
#                    random_state=42)

# %%
best_estimator = random_search.best_estimator_
best_params = random_search.best_params_
best_params
best_estimator
# Out:
# HistGradientBoostingClassifier(l2_regularization=0.3042422429595377,
#                                learning_rate=0.11495128632644756, max_depth=3,
#                                min_samples_leaf=4)

# %%
new0=HistGradientBoostingClassifier(l2_regularization=0.3042422429595377,
                               learning_rate=0.11495128632644756, max_depth=3,
                               min_samples_leaf=4)
new0.fit(X_train_sm,y_train_sm)
# Out:
# HistGradientBoostingClassifier(l2_regularization=0.3042422429595377,
#                                learning_rate=0.11495128632644756, max_depth=3,
#                                min_samples_leaf=4)

# %%
accuracy = round(new0.score(X_test, y_test)*100,2)
print(round(accuracy, 2), '%')
# Out:
# 65.0 %

# %%
import matplotlib .pyplot as plt
from sklearn.model_selection import learning_curve
train_sizes,train_scores,test_scores=learning_curve(new0,X_train_sm,y_train_sm,cv=5,n_jobs=-1,train_sizes=np.linspace(0.1,1,10))
train_score_mean=np.mean(train_scores,axis=1)
train_score_median=np.median(train_scores,axis=1)
test_score_mean=np.mean(test_scores,axis=1)
test_score_median=np.median(test_scores,axis=1)

plt.figure(figsize=(10,6))
plt.fill_between(train_sizes, train_score_mean - train_score_median,
                 train_score_mean + train_score_median, alpha=0.1, color="r")
plt.fill_between(train_sizes, test_score_mean - test_score_median,
                 test_score_mean + test_score_median, alpha=0.1, color="g")
plt.plot(train_sizes, train_score_mean, 'o-', color="r",
         label="Training score")
plt.plot(train_sizes, test_score_mean, 'o-', color="g",
         label="Cross-validation score")
plt.xlabel("Training examples")
plt.ylabel("Score")
plt.legend(loc="best")
plt.title("Learning Curve (Random Forest)")
plt.grid()
plt.show()

# %%
from sklearn.ensemble import RandomForestClassifier
new2=RandomForestClassifier(n_estimators=1,random_state=42,n_jobs=-1)
new2.fit(X_train_sm,y_train_sm)
# Out:
# RandomForestClassifier(n_estimators=1, n_jobs=-1, random_state=42)

# %%
from sklearn.model_selection import RandomizedSearchCV,KFold
from scipy.stats import randint
param_distributions={'n_estimators':randint(100,500),
                     'max_depth': [None,10,20,30,40,50],
                     'min_samples_split': randint(2,20),
                      'min_samples_leaf': randint(1, 20),
                     'max_features':['sqrt','log2'],
                     'bootstrap':[True,False]
                     }
random_search = RandomizedSearchCV(new2, param_distributions, random_state=42)
random_search.fit(X_train_sm, y_train_sm)
# Out:
# RandomizedSearchCV(estimator=RandomForestClassifier(n_estimators=1, n_jobs=-1,
#                                                     random_state=42),
#                    param_distributions={'bootstrap': [True, False],
#                                         'max_depth': [None, 10, 20, 30, 40, 50],
#                                         'max_features': ['sqrt', 'log2'],
#                                         'min_samples_leaf': <scipy.stats._distn_infrastructure.rv_discrete_frozen object at 0x000001F42CF02E90>,
#                                         'min_samples_split': <scipy.stats._distn_infrastructure.rv_discrete_frozen object at 0x000001F42ABEFD50>,
#                                         'n_estimators': <scipy.stats._distn_infrastructure.rv_discrete_frozen object at 0x000001F42ABD69D0>},
#                    random_state=42)

# %%
best_estimator1 = random_search.best_estimator_
best_params1 = random_search.best_params_
best_params1
best_estimator1
# Out:
# RandomForestClassifier(bootstrap=False, max_depth=50, max_features='log2',
#                        min_samples_leaf=2, n_estimators=413, n_jobs=-1,
#                        random_state=42)

# %%
new1=RandomForestClassifier(bootstrap=False, max_depth=50, max_features='log2',
                       min_samples_leaf=2, n_estimators=413, n_jobs=-1,
                       random_state=42)
new1.fit(X_train_sm,y_train_sm)
# Out:
# RandomForestClassifier(bootstrap=False, max_depth=50, max_features='log2',
#                        min_samples_leaf=2, n_estimators=413, n_jobs=-1,
#                        random_state=42)

# %%
mlaccuracy8 = round(new1.score(X_test, y_test)*100,2)
print(round(mlaccuracy8, 2), '%')
# Out:
# 50.0 %

# %%
import matplotlib .pyplot as plt
from sklearn.model_selection import learning_curve
train_sizes,train_scores,test_scores=learning_curve(new1,X_train_sm,y_train_sm,cv=5,n_jobs=-1,train_sizes=np.linspace(0.1,1,10))
train_score_mean=np.mean(train_scores,axis=1)
train_score_median=np.median(train_scores,axis=1)
test_score_mean=np.mean(test_scores,axis=1)
test_score_median=np.median(test_scores,axis=1)

plt.figure(figsize=(10,6))
plt.fill_between(train_sizes, train_score_mean - train_score_median,
                 train_score_mean + train_score_median, alpha=0.1, color="r")
plt.fill_between(train_sizes, test_score_mean - test_score_median,
                 test_score_mean + test_score_median, alpha=0.1, color="g")
plt.plot(train_sizes, train_score_mean, 'o-', color="r",
         label="Training score")
plt.plot(train_sizes, test_score_mean, 'o-', color="g",
         label="Cross-validation score")
plt.xlabel("Training examples")
plt.ylabel("Score")
plt.legend(loc="best")
plt.title("Learning Curve (Random Forest)")
plt.grid()
plt.show()
